# %% [markdown]
# # Probability exercises

# %% [markdown]
# ## Exercise 1
#
# Two dices are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7.  A simulation is a repetition of the same experiment multiple times to observe its behavior:
#
# - Run the experiment 1000 times (roll 2 dice 1000 times, and sum the number of both dices).
# - Keep track of the number of times that the sum was either greater than 7 or an even number.
# - Divide the number from step 2 by the number of iterations (1000).

# %%
# TODO
import numpy as np 
import random

counter=0
for i in range(1000):
  dado1=np.random.randint(1,7)
  dado2=np.random.randint(1,7)
  sum_d= dado1+dado2
  if ((sum_d>7) or (sum_d%2==0)):
    counter+=1
prob=counter/(i+1)
print(prob)
# Out:
# 0.655

# %% [markdown]
# ## Exercise 2
#
# A box contains 10 white balls, 20 red balls and 30 green balls. If we take 5 balls from the box with replacement (we take the ball, observe what color it is and put it back into the box). We want to know the probability of:
#
# 1. Take 3 white and 2 red.
# 2. All are the same color.
#
# Run the experiment 1000 times and calculate the above probabilities.

# %%
import numpy as np

# Create the box of balls with 10 white balls, 20 red balls and 30 green balls 
ball_colors = np.concatenate([np.full(10, "White"), np.full(20, "Red"), np.full(30, "Green")])

# Shuffle the box
np.random.shuffle(ball_colors)

# Display the box
print(ball_colors)

#define function
def take_balls(n_simulations=1000):
    count_1 = 0
    count_2 = 0

    for _ in range(n_simulations):
        # Take randomly 5 balls from the box with replacement, so putting the ball back in the box once you see the color
        colors = np.random.choice(ball_colors, 5, replace=True)

        # Count the colors
        white_balls = np.sum(colors == "White")
        red_balls = np.sum(colors == "Red")
        green_balls = np.sum(colors == "Green")

        # Decide if we should add it to the count:
        if (white_balls == 3) and (red_balls == 2):
            count_1 += 1

        if (white_balls == 5) or (red_balls == 5) or (green_balls == 5):
            count_2 += 1

    return count_1 / n_simulations, count_2 / n_simulations

# Simulate and get probabilities
probabilities = take_balls(1000)

# Display the results rounding to 2 decimals 0 being position for count_1 and 1 for count_2
print(f"The probability of 3 white and 2 red is: {np.round(probabilities[0] * 100, 2)}%")
print(f"The probability of all the same color is: {np.round(probabilities[1] * 100, 2)}%")
# Out:
# ['Red' 'Green' 'Green' 'White' 'Green' 'White' 'Red' 'Green' 'White' 'Red'
#  'Green' 'White' 'Green' 'Green' 'Green' 'Green' 'Red' 'Green' 'Red' 'Red'
#  'Green' 'Red' 'Red' 'Red' 'White' 'Green' 'Green' 'Green' 'Green' 'Green'
#  'Red' 'Green' 'Red' 'Green' 'Green' 'Green' 'White' 'Green' 'White' 'Red'
#  'Red' 'Green' 'White' 'Red' 'White' 'White' 'Green' 'Green' 'Red' 'Red'
#  'Green' 'Green' 'Green' 'Red' 'Green' 'Red' 'Red' 'Green' 'Red' 'Green']
# The probability of 3 white and 2 red is: 0.5%
# The probability of all the same color is: 4.0%
